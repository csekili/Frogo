# %%
import numpy as np
from keras.models import Sequential, Model
from keras.layers import Activation, Dense, Flatten, Input
from tensorflow.python.keras.layers import GRU
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping
# from keras.wrappers import scikit_learn
# from keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import tensorflow as tf
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from keras.layers import LSTM

import tensorflow as tf
from keras import backend as K

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction=0.05
session = tf.Session(config=config) # Letrehozunk egy TF session-t a megfelelo mem. korlattal
K.set_session(session) # atadjuk azt a Kerasnak
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <h3>Loading dataset</h3>

# %%
import pandas as pd
import numpy as np

# import csv
df = pd.read_csv('modified_dataset.csv', 
                 dtype={'Temperature':str, 
                        'Pressure0':str, 
                        'Humidity':str, 
                        'Wind_speed':str}, 
                 delimiter=';', 
                 na_filter=False)
print("Sneak peak of the data set:")
df.head()

#excluding the timestamp form the input features and
#setting output to be the temperature of following day

X = np.array(df.loc[:,(df.columns != 'Time')].values)

no_samples= X.shape[0]
print(X.shape[0])

X = X[0:(no_samples-1) , :]
Y = X[1:no_samples , 0]

no_samples = X.shape[0]
print(X.shape[0])

print(Y.shape)
print(X[:,0].shape)
# Out:
# Sneak peak of the data set:
# 63135
# 63134
# (63133,)
# (63134,)

# %% [markdown]
# <h3>Preparing input and output sequence</h3>

# %%
for idx, val in enumerate(X[:,0]):
    if val=='':
        X[:,0][idx] = (np.float64(X[:,0][idx-1])+np.float64(X[:,0][idx+1]))/2
    else:
        X[:,0][idx] = np.float64(val)
        
for idx, val in enumerate(X[:,1]):
    if val=='':
        X[:,1][idx] = (np.float64(X[:,1][idx-1])+np.float64(X[:,1][idx+1]))/2
    else:
        X[:,1][idx] = np.float64(val)
        

for idx, val in enumerate(X[:,2]):
    if val=='':
        X[:,2][idx] = (int(X[:,2][idx-1])+int(X[:,2][idx+1]))/2
    else:
        X[:,2][idx] = int(val)
        
for idx, val in enumerate(X[:,3]):
    if val=='':
        X[:,3][idx] = (int(X[:,3][idx-1])+int(X[:,3][idx+1]))/2
    else:
        X[:,3][idx] = int(val)
        
for idx, val in enumerate(X[:,4]):
    if val=='':
        X[:,4][idx] = (int(X[:,4][idx-1])+int(X[:,4][idx+1]))/2
    else:
        X[:,4][idx] = int(val)
        
for idx, val in enumerate(Y):
    if val=='':
        Y[idx] = (int(Y[idx-1])+int(Y[idx+1]))/2
    else:
        Y[idx] = int(val)

print(Y.shape)
Y2=np.zeros((63132,2), dtype='float64')
Y2[0:63132, 1] = Y[0:63132]
Y2[0:63132, 0] = Y[1:63133]

X2 = X[1:63133,:]

X=X2
Y=Y2
# Out:
# (63133,)

# %% [markdown]
# <h3>Preprocessing data</h3>

# %%
nb_samples = len(X)
test_split = 0.2

# splitting train-validation-test sets
X_train = X[0:int(nb_samples*(1-test_split))].astype(np.float32)
Y_train = Y[0:int(nb_samples*(1-test_split))].astype(np.float32)
X_test  = X[int(nb_samples*(1-test_split)):].astype(np.float32)
Y_test  = Y[int(nb_samples*(1-test_split)):].astype(np.float32)

print("train set dims:")
print(X_train.shape)
print(Y_train.shape)
print("test set dims:")
print(X_test.shape)
print(Y_test.shape)

#tsandardizing
print('\nmean of X_train')
print(np.mean(X_train,0))
print('\nstd dev of X_train')
print(np.std(X_train, 0))

#mean
atl0= np.mean(X_train, axis=0)
X_train -= np.expand_dims(atl0, 0)
X_test  -= np.expand_dims(atl0, 0)

#std
std0 = np.std(X_train, axis=0)
X_train /= np.expand_dims(std0,0)
X_test  /= np.expand_dims(std0,0)
# Out:
# train set dims:
# (50505, 40)
# (50505, 2)
# test set dims:
# (12627, 40)
# (12627, 2)
#
# mean of X_train
# [1.0397327e+01 7.4943433e+02 7.6277643e+02 7.5826118e+01 3.3851302e+00
#  1.3180873e-01 7.5020295e-01 2.3106623e-02 8.5278682e-02 5.2826453e-02
#  2.0908821e-02 1.0078210e-02 8.7120087e-04 8.8308090e-03 1.3860014e-04
#  5.9400059e-05 8.8585287e-02 3.7243836e-02 4.2550243e-02 3.4768835e-02
#  3.6234036e-02 2.0968221e-02 1.4652015e-02 5.5776656e-02 8.1417680e-02
#  4.2292841e-02 2.3720425e-02 2.1641422e-02 3.2630432e-02 3.3264033e-02
#  2.5557867e-01 5.3499654e-02 9.6287496e-02 2.8828830e-02 7.6230075e-03
#  9.2782892e-02 1.2525493e-01 5.8192259e-01 6.4290665e-02 1.2812592e-01]
#
# std dev of X_train
# [9.7296915e+00 5.9496026e+00 6.1733961e+00 2.0032450e+01 2.1750824e+00
#  3.3828270e-01 4.3289548e-01 1.5024216e-01 2.7929595e-01 2.2368687e-01
#  1.4307916e-01 9.9883132e-02 2.9503254e-02 9.3556531e-02 1.1772040e-02
#  7.7069141e-03 2.8414422e-01 1.8935874e-01 2.0184085e-01 1.8319380e-01
#  1.8687196e-01 1.4327790e-01 1.2015545e-01 2.2948992e-01 2.7347547e-01
#  2.0125645e-01 1.5217675e-01 1.4550970e-01 1.7766733e-01 1.7932522e-01
#  4.3618599e-01 2.2502765e-01 2.9498512e-01 1.6732521e-01 8.6976416e-02
#  2.9012793e-01 3.3100775e-01 4.9324304e-01 2.4527001e-01 3.3423001e-01]

# %% [markdown]
# <h3>Loss function definition</h3>

# %%
import keras.backend as K

def patkolt_loss(x0, alpha = 0.0):
    def vori(y_true, y_pred):
        constr = K.maximum(K.abs(y_pred- (x0*std0[0] +atl0[0])) - 12.0 ,
                           0.0)
        mse = K.square(y_pred-y_true)
        return(K.mean(mse + alpha*constr))
    
    return vori


def nemvori(y_true, y_pred):
    mse= K.square(y_true-y_pred)
    return(K.mean(mse))

# %% [markdown]
# <h3>Model definition</h3>

# %%
adam=Adam(lr=0.001, 
          beta_1=0.9, 
          beta_2=0.999, 
          epsilon=None, 
          decay=0.0, 
          amsgrad=False)

def model(alfa = 0.0):
    def modelfn():
        bem = Input(shape=(40,), dtype='float32')
        kim = Dense(10, activation='relu')(bem)
        kim = Dense(4, activation='relu')(kim)
        kim = Dense(1, activation='relu')(kim)
        model= Model(bem, kim)
        model.compile(loss = patkolt_loss(bem[:,0]), 
                      optimizer = adam, 
                      metrics = ['mse', patkolt_loss(bem[:,0], alpha= alfa)])
        print(model.summary())
        return model
    return modelfn()
# Out:
# WARNING:tensorflow:From C:\Users\admin\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# <h3> Training </h3>

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                              min_delta=0, 
                              patience=5, 
                              verbose=0, 
                              mode='auto', 
                              baseline=None, 
                              restore_best_weights=True)

print("msemodel")
msemodel = model(alfa = 0.0)
msehst = msemodel.fit(X_train[:,:], 
                      Y_train[:,0], 
                      verbose=1, 
                      batch_size=16, 
                      epochs=35, 
                      validation_split=0.1, 
                      callbacks = [early_stopping])

print('\nctrmodel')
ctrmodel = model(alfa = 1.0)
ctrhst = ctrmodel.fit(X_train[:,:], 
                      Y_train[:,0], 
                      verbose=1, 
                      batch_size=16, 
                      epochs=35, 
                      validation_split=0.1, 
                      callbacks = [early_stopping])

print('\nalphamodel')
alphamodel = model(alfa=0.5)
alphahst = alphamodel.fit(X_train[:,:], 
                          Y_train[:,0], 
                          verbose=1, 
                          batch_size=16, 
                          epochs=35, 
                          validation_split=0.1, 
                          callbacks = [early_stopping])
# Out:
# msemodel
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 44
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 459
# Trainable params: 459
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 45454 samples, validate on 5051 samples
# Epoch 1/35
# 45454/45454 [==============================] - 3s 57us/step - loss: 26.8909 - mean_squared_error: 26.8909 - vori: 26.8909 - val_loss: 6.7306 - val_mean_squared_error: 6.7306 - val_vori: 6.7306
# Epoch 2/35
# 45454/45454 [==============================] - 3s 56us/step - loss: 4.8146 - mean_squared_error: 4.8146 - vori: 4.8146 - val_loss: 6.2800 - val_mean_squared_error: 6.2800 - val_vori: 6.2800
# Epoch 3/35
# 45454/45454 [==============================] - 3s 58us/step - loss: 4.6345 - mean_squared_error: 4.6345 - vori: 4.6345 - val_loss: 6.0752 - val_mean_squared_error: 6.0752 - val_vori: 6.0752
# Epoch 4/35
# 45454/45454 [==============================] - 3s 58us/step - loss: 4.5723 - mean_squared_error: 4.5723 - vori: 4.5723 - val_loss: 6.0170 - val_mean_squared_error: 6.0170 - val_vori: 6.0170
# Epoch 5/35
# 45454/45454 [==============================] - 3s 66us/step - loss: 4.5403 - mean_squared_error: 4.5403 - vori: 4.5403 - val_loss: 5.9778 - val_mean_squared_error: 5.9778 - val_vori: 5.9778
# Epoch 6/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.5192 - mean_squared_error: 4.5192 - vori: 4.5192 - val_loss: 5.9613 - val_mean_squared_error: 5.9613 - val_vori: 5.9613
# Epoch 7/35
# 45454/45454 [==============================] - 2s 49us/step - loss: 4.5073 - mean_squared_error: 4.5073 - vori: 4.5073 - val_loss: 5.9458 - val_mean_squared_error: 5.9458 - val_vori: 5.9458
# Epoch 8/35
# 45454/45454 [==============================] - 2s 55us/step - loss: 4.4998 - mean_squared_error: 4.4998 - vori: 4.4998 - val_loss: 5.9765 - val_mean_squared_error: 5.9765 - val_vori: 5.9765
# Epoch 9/35
# 45454/45454 [==============================] - 2s 51us/step - loss: 4.4937 - mean_squared_error: 4.4937 - vori: 4.4937 - val_loss: 5.9527 - val_mean_squared_error: 5.9527 - val_vori: 5.9527
# Epoch 10/35
# 45454/45454 [==============================] - 2s 47us/step - loss: 4.4874 - mean_squared_error: 4.4874 - vori: 4.4874 - val_loss: 5.9691 - val_mean_squared_error: 5.9691 - val_vori: 5.9691
# Epoch 11/35
# 45454/45454 [==============================] - 3s 69us/step - loss: 4.4833 - mean_squared_error: 4.4833 - vori: 4.4833 - val_loss: 5.9667 - val_mean_squared_error: 5.9667 - val_vori: 5.9667
# Epoch 12/35
35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.4006 - mean_squared_error: 4.4006 - vori: 6.8250 - val_loss: 5.9289 - val_mean_squared_error: 5.9289 - val_vori: 5.9291
# Epoch 21/35
# 45454/45454 [==============================] - 2s 52us/step - loss: 4.3956 - mean_squared_error: 4.3956 - vori: 6.8040 - val_loss: 5.9271 - val_mean_squared_error: 5.9271 - val_vori: 5.9273
# Epoch 22/35
# 45454/45454 [==============================] - 2s 55us/step - loss: 4.3951 - mean_squared_error: 4.3951 - vori: 6.8087 - val_loss: 5.9047 - val_mean_squared_error: 5.9047 - val_vori: 5.9049
# Epoch 23/35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.3920 - mean_squared_error: 4.3920 - vori: 6.8155 - val_loss: 5.9043 - val_mean_squared_error: 5.9043 - val_vori: 5.9045
# Epoch 24/35
# 45454/45454 [==============================] - 3s 60us/step - loss: 4.3875 - mean_squared_error: 4.3875 - vori: 6.8043 - val_loss: 5.8508 - val_mean_squared_error: 5.8508 - val_vori: 5.8510
# Epoch 25/35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.3845 - mean_squared_error: 4.3845 - vori: 6.8010 - val_loss: 5.8634 - val_mean_squared_error: 5.8634 - val_vori: 5.8636
# Epoch 26/35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.3814 - mean_squared_error: 4.3814 - vori: 6.8031 - val_loss: 5.8418 - val_mean_squared_error: 5.8418 - val_vori: 5.8420
# Epoch 27/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.3834 - mean_squared_error: 4.3834 - vori: 6.8086 - val_loss: 5.8437 - val_mean_squared_error: 5.8437 - val_vori: 5.8439
# Epoch 28/35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.3816 - mean_squared_error: 4.3816 - vori: 6.8136 - val_loss: 5.8595 - val_mean_squared_error: 5.8595 - val_vori: 5.8597
# Epoch 29/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.3801 - mean_squared_error: 4.3801 - vori: 6.8008 - val_loss: 5.8558 - val_mean_squared_error: 5.8558 - val_vori: 5.8560
# Epoch 30/35
# 45454/45454 [==============================] - 3s 60us/step - loss: 4.3767 - mean_squared_error: 4.3767 - vori: 6.7985 - val_loss: 5.8367 - val_mean_squared_error: 5.8367 - val_vori: 5.8369
# Epoch 31/35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.3783 - mean_squared_error: 4.3783 - vori: 6.7962 - val_loss: 5.8388 - val_mean_squared_error: 5.8388 - val_vori: 5.8390
# Epoch 32/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.3759 - mean_squared_error: 4.3759 - vori: 6.7857 - val_loss: 5.8635 - val_mean_squared_error: 5.8635 - val_vori: 5.8637
# Epoch 33/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.3745 - mean_squared_error: 4.3745 - vori: 6.7914 - val_loss: 5.8334 - val_mean_squared_error: 5.8334 - val_vori: 5.8336
# Epoch 34/35
# 45454/45454 [==============================] - 3s 56us/step - loss: 4.3746 - mean_squared_error: 4.3746 - vori: 6.7980 - val_loss: 5.8288 - val_mean_squared_error: 5.8288 - val_vori: 5.8291
# Epoch 35/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.3761 - mean_squared_error: 4.3761 - vori: 6.7885 - val_loss: 5.8356 - val_mean_squared_error: 5.8356 - val_vori: 5.8358
#
# alphamodel
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 40)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 44
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 459
# Trainable params: 459
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 45454 samples, validate on 5051 samples
# Epoch 1/35
# 45454/45454 [==============================] - 3s 68us/step - loss: 13.6479 - mean_squared_error: 13.6479 - vori: 14.8379 - val_loss: 6.4042 - val_mean_squared_error: 6.4042 - val_vori: 6.4043
# Epoch 2/35
# 45454/45454 [==============================] - 3s 55us/step - loss: 4.7366 - mean_squared_error: 4.7366 - vori: 5.9491 - val_loss: 6.1192 - val_mean_squared_error: 6.1192 - val_vori: 6.1193
# Epoch 3/35
# 45454/45454 [==============================] - 3s 56us/step - loss: 4.5953 - mean_squared_error: 4.5953 - vori: 5.8067 - val_loss: 6.0203 - val_mean_squared_error: 6.0203 - val_vori: 6.0204
# Epoch 4/35
# 45454/45454 [==============================] - 3s 57us/step - loss: 4.5459 - mean_squared_error: 4.5459 - vori: 5.7566 - val_loss: 5.9772 - val_mean_squared_error: 5.9772 - val_vori: 5.9773
# Epoch 5/35
# 45454/45454 [==============================] - 3s 55us/step - loss: 4.5210 - mean_squared_error: 4.5210 - vori: 5.7319 - val_loss: 5.9733 - val_mean_squared_error: 5.9733 - val_vori: 5.9735
# Epoch 6/35
# 45454/45454 [==============================] - 3s 56us/step - loss: 4.5042 - mean_squared_error: 4.5042 - vori: 5.7175 - val_loss: 5.9556 - val_mean_squared_error: 5.9556 - val_vori: 5.9557
# Epoch 7/35
# 45454/45454 [==============================] - 3s 61us/step - loss: 4.4944 - mean_squared_error: 4.4944 - vori: 5.7067 - val_loss: 5.9708 - val_mean_squared_error: 5.9708 - val_vori: 5.9711
# Epoch 8/35
# 45454/45454 [==============================] - 3s 58us/step - loss: 4.4849 - mean_squared_error: 4.4849 - vori: 5.6978 - val_loss: 5.9443 - val_mean_squared_error: 5.9443 - val_vori: 5.9445
# Epoch 9/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.4757 - mean_squared_error: 4.4757 - vori: 5.6903 - val_loss: 5.9669 - val_mean_squared_error: 5.9669 - val_vori: 5.9672
# Epoch 10/35
# 45454/45454 [==============================] - 3s 56us/step - loss: 4.4728 - mean_squared_error: 4.4728 - vori: 5.6862 - val_loss: 5.9240 - val_mean_squared_error: 5.9240 - val_vori: 5.9242
# Epoch 11/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.4683 - mean_squared_error: 4.4683 - vori: 5.6847 - val_loss: 5.9515 - val_mean_squared_error: 5.9515 - val_vori: 5.9517
# Epoch 12/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.4532 - mean_squared_error: 4.4532 - vori: 5.6709 - val_loss: 5.9388 - val_mean_squared_error: 5.9388 - val_vori: 5.9389
# Epoch 13/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.4150 - mean_squared_error: 4.4150 - vori: 5.6260 - val_loss: 5.9133 - val_mean_squared_error: 5.9133 - val_vori: 5.9135
# Epoch 14/35
# 45454/45454 [==============================] - 3s 62us/step - loss: 4.4064 - mean_squared_error: 4.4064 - vori: 5.6216 - val_loss: 5.9271 - val_mean_squared_error: 5.9271 - val_vori: 5.9274
# Epoch 15/35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.4010 - mean_squared_error: 4.4010 - vori: 5.6135 - val_loss: 5.9273 - val_mean_squared_error: 5.9273 - val_vori: 5.9275
# Epoch 16/35
# 45454/45454 [==============================] - 2s 53us/step - loss: 4.3999 - mean_squared_error: 4.3999 - vori: 5.6089 - val_loss: 5.9186 - val_mean_squared_error: 5.9186 - val_vori: 5.9187
# Epoch 17/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.4030 - mean_squared_error: 4.4030 - vori: 5.6146 - val_loss: 5.9376 - val_mean_squared_error: 5.9376 - val_vori: 5.9378
# Epoch 18/35
# 45454/45454 [==============================] - 2s 54us/step - loss: 4.3982 - mean_squared_error: 4.3982 - vori: 5.6033 - val_loss: 5.9293 - val_mean_squared_error: 5.9293 - val_vori: 5.9295

# %%
print("msemodel training  and validation metrics")
fig=plt.figure(figsize=(30, 10))
fig.add_subplot(1, 2, 1)
plt.title('Training')
plt.plot(msehst.history['loss'])
plt.plot(msehst.history['mean_squared_error'])
plt.plot(msehst.history['vori'])

fig.add_subplot(1, 2 ,2)
plt.title("Validation")
plt.plot(msehst.history['val_loss'])
plt.plot(msehst.history['val_mean_squared_error'])
plt.plot(msehst.history['val_vori'])
plt.show()

print("ctrmodel training and validation metrics")
fig=plt.figure(figsize=(30, 10))
fig.add_subplot(1, 2, 1)
plt.title('Training')
plt.plot(ctrhst.history['loss'])
plt.plot(ctrhst.history['mean_squared_error'])
plt.plot(ctrhst.history['vori'])

fig.add_subplot(1, 2 ,2)
plt.title("Validation")
plt.plot(ctrhst.history['val_loss'])
plt.plot(ctrhst.history['val_mean_squared_error'])
plt.plot(ctrhst.history['val_vori'])
plt.show()

print("alphamodel training and validation metrics")
fig=plt.figure(figsize=(30, 10))
fig.add_subplot(1, 2, 1)
plt.title('Training')
plt.plot(alphahst.history['loss'])
plt.plot(alphahst.history['mean_squared_error'])
plt.plot(alphahst.history['vori'])

fig.add_subplot(1, 2 ,2)
plt.title("Validation")
plt.plot(alphahst.history['val_loss'])
plt.plot(alphahst.history['val_mean_squared_error'])
plt.plot(alphahst.history['val_vori'])
plt.show()
# Out:
# msemodel training  and validation metrics
# ctrmodel training and validation metrics
# alphamodel training and validation metrics

# %% [markdown]
# <h3>Predicting</h3>

# %%
msepred=msemodel.predict(X_test)
ctrpred=ctrmodel.predict(X_test)
alphapred=alphamodel.predict(X_test)

# %%
fig=plt.figure(figsize=(30, 10))
plt.plot(Y_test[::48,0], color='red')
plt.plot(msepred[::48], color='blue')
plt.title('mse prediction')
plt.show()

fig=plt.figure(figsize=(30, 10))
plt.plot(Y_test[::48,0], color='red')
plt.plot(ctrpred[::48], color='blue')
plt.title('ctr prediction')
plt.show()

fig=plt.figure(figsize=(30, 10))
plt.plot(Y_test[::48,0], color='red')
plt.plot(alphapred[::48], color='blue')
plt.title('alpha prediction')
plt.show()

# %%
mseabs = []
for i in range(len(Y_test)):
    mseabs.append(abs(msepred[i] - Y_test[i,0]))
fig=plt.figure(figsize=(30, 10))
plt.plot(mseabs[::48])
plt.plot(Y_test[::48,0])
plt.title('Absolute error, msemodel')
plt.show()

ctrabs = []
for i in range(len(Y_test)):
    ctrabs.append(abs(ctrpred[i] - Y_test[i,0]))
fig=plt.figure(figsize=(30, 10))
plt.plot(ctrabs[::48])
plt.plot(Y_test[::48,0])
plt.title('Absolute error, ctrmodel')
plt.show()

alphaabs = []
for i in range(len(Y_test)):
    alphaabs.append(abs(alphapred[i] - Y_test[i,0]))
fig=plt.figure(figsize=(30, 10))
plt.plot(alphaabs[::48])
plt.plot(Y_test[::48,0])
plt.title('Absolute error, alphamodel')
plt.show()

fig=plt.figure(figsize=(30, 10))
plt.title('Absolute error')
plt.plot(alphaabs[::48], color='green')
plt.plot(mseabs[::48], color = 'blue')
plt.plot(ctrabs[::48], color = 'red')
